# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('t20i_info.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0           0         2    Australia    Sri Lanka   0.1     0
# 1           1         2    Australia    Sri Lanka   0.2     0
# 2           2         2    Australia    Sri Lanka   0.3     1
# 3           3         2    Australia    Sri Lanka   0.4     2
# 4           4         2    Australia    Sri Lanka   0.5     0
#
#   player_dismissed city                     venue
# 0                0  NaN  Melbourne Cricket Ground
# 1                0  NaN  Melbourne Cricket Ground
# 2                0  NaN  Melbourne Cricket Ground
# 3                0  NaN  Melbourne Cricket Ground
# 4                0  NaN  Melbourne Cricket Ground

# %%
# batting team
# bowling team
# city
# current_score
# balls left
# wickets_left
# current_run_rate
# last five

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'][0].split(' ')[0]
# Out:
# 'Melbourne'

# %%
cities = np.where(df['city'].isnull(), df['venue'].str.split().apply(lambda x : x[0]), df['city'])

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed       city                     venue
# 0                    0  Melbourne  Melbourne Cricket Ground
# ...

# %%
df['current_score'] = df.groupby('match_id')['runs'].cumsum()

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed       city                     venue  current_score
# 0                    0  Melbourne  Melbourne Cricket Ground              0
# ...

# %%
df['over'] = df['ball'].apply(lambda x : str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x : str(x).split(".")[1])

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed       city                     venue  current_score  \
# 0                    0  Melbourne  Melbourne Cricket Ground              0
# ...

# %%
df['balls_bowled'] = (df['over'].astype('int')*6 + df['ball_no'].astype('int'))

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed       city                     venue  current_score  \
# 0                    0  Melbourne  Melbourne Cricket Ground              0
# ...

# %%
df['balls_left'] = 120 - df['balls_bowled']

# %%
df['balls_left'] = df['balls_left'].apply(lambda x: 0 if x < 0 else x)

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed       city                     venue  current_score  \
# 0                    0  Melbourne  Melbourne Cricket Ground              0
# ...

# %%
df['player_dismissed'].apply(lambda x: 1 if x != '0' else '0')
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 63883    0
# 63884    0
# 63885    1
# 63886    0
# 63887    0
# Name: player_dismissed, Length: 50501, dtype: object

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x: 1 if x != '0' else 0)

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#        player_dismissed       city                     venue  current_score  \
# 0                     0  Melbourne  Melbourne Cricket Ground              0
# ...

# %%
df['player_dismissed'] = df['player_dismissed'].astype('int')

# %%
df['player_dismissed'] = df.groupby('match_id')['player_dismissed'].cumsum()

# %%
df['wickets_left'] = 10 - df['player_dismissed']

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#        player_dismissed       city                     venue  current_score  \
# 0                     0  Melbourne  Melbourne Cricket Ground              0
# ...

# %%
df['crr'] = (df['current_score']*6) / df['balls_bowled']

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#        player_dismissed       city                     venue  current_score  \
# 0                     0  Melbourne  Melbourne Cricket Ground              0
# ...

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id)['runs'].rolling(window=30).sum().values.tolist())

# %%
df['last_five'] = last_five

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#        player_dismissed       city                     venue  current_score  \
# 0                     0  Melbourne  Melbourne Cricket Ground              0
# ...

# %%
final_df = df.groupby('match_id')['runs'].sum().reset_index().merge(df,on='match_id')

# %%
final_df
# Out:
#        match_id  runs_x  Unnamed: 0 batting_team bowling_team  ball  runs_y  \
# 0             2     168           0    Australia    Sri Lanka   0.1       0
# 1             2     168           1    Australia    Sri Lanka   0.2       0
# 2             2     168           2    Australia    Sri Lanka   0.3       1
# 3             2     168           3    Australia    Sri Lanka   0.4       2
# 4             2     168           4    Australia    Sri Lanka   0.5       0
# ...         ...     ...         ...          ...          ...   ...     ...
# 50496       964     128         121    Sri Lanka    Australia  19.3       1
# 50497       964     128         122    Sri Lanka    Australia  19.4       0
# 50498       964     128         123    Sri Lanka    Australia  19.5       0
# 50499       964     128         124    Sri Lanka    Australia  19.6       2
# 50500       964     128         125    Sri Lanka    Australia  19.7       1
#
# ...

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df = final_df.dropna(axis=1)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# runs_x           0
# dtype: int64

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
#       batting_team bowling_team         city  current_score  balls_left  \
# 3253   Afghanistan  West Indies     St Kitts             21          99
# 49269        India  West Indies       Mumbai            102          45
# 28913  West Indies     Pakistan     St Lucia             32          92
# 7355     Australia        India       Sydney             28          96
# 40642    Sri Lanka  New Zealand   Chittagong             65          53
# ...            ...          ...          ...            ...         ...
# 11955    Australia      England  Southampton            157           0
# 7473    Bangladesh  West Indies     St Kitts             16         104
# 21972    Sri Lanka     Pakistan       London             95          21
# 16383   Bangladesh    Australia    Cape Town            108          20
# 40399     Pakistan   Bangladesh       Mirpur            112          41
#
#        wickets_left       crr  runs_x
# 3253              9  6.000000     110
# ...

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#        batting_team  bowling_team        city  current_score  balls_left  \
# 47625     Sri Lanka   West Indies   Bangalore             41          83
# 13292     Australia         India      Sydney            169          11
# 49822     Sri Lanka         India      Mirpur             18          90
# 39287     Sri Lanka  South Africa  Chittagong            134          23
# 3227    West Indies      Pakistan    Trinidad            122           4
# ...             ...           ...         ...            ...         ...
# 50379     Sri Lanka     Australia     Colombo              7         115
# 35918   New Zealand       England  Wellington             50          72
# 25440     Australia     Sri Lanka    Barbados            144          10
# 32673   New Zealand       England   Pallekele             68          46
# 46695  South Africa     Sri Lanka   Cape Town            107          39
#
#        wickets_left       crr
# 47625             7  6.648649
# ...

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
# !{sys.executable} -m pip install xgboost

# %%
pip install -U scikit-learn
# Out:
# ...
#
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

# Assuming X is your input data
# Make sure to replace X with your actual input data
# And specify the correct column names for 'batting_team', 'bowling_team', and 'city'

# Replace the column names below with the actual column names in your dataset
batting_team_col = 'batting_team'
bowling_team_col = 'bowling_team'
city_col = 'city'

# Assuming X is your input data
# Make sure to replace X with your actual input data
# And specify the correct column names for 'batting_team', 'bowling_team', and 'city'

# Define the columns to be transformed
categorical_cols = [batting_team_col, bowling_team_col, city_col]

# Create a ColumnTransformer
trf = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(sparse_output=False, drop='first'), categorical_cols)
    ],
    remainder='passthrough'
)

# Apply the transformation
X_transformed = trf.fit_transform(X)

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9667640328407288
# 2.3255033822546336

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
eligible_cities
# Out:
# ['Colombo',
#  'Mirpur',
#  'Johannesburg',
#  'Dubai',
#  'Auckland',
#  'Cape Town',
#  'London',
#  'Pallekele',
#  'Barbados',
#  'Sydney',
#  'Melbourne',
#  'Durban',
#  'St Lucia',
#  'Wellington',
#  'Lauderhill',
#  'Hamilton',
#  'Centurion',
#  'Manchester',
#  'Abu Dhabi',
#  'Mumbai',
#  'Nottingham',
#  'Southampton',
#  'Mount Maunganui',
#  'Chittagong',
#  'Kolkata',
#  'Lahore',
#  'Delhi',
#  'Nagpur',
#  'Chandigarh',
#  'Adelaide',
#  'Bangalore',
#  'St Kitts',
#  'Cardiff',
#  'Christchurch',
#  'Trinidad']
